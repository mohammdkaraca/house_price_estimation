# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
from scipy import stats

# %%
df = pd.read_csv('home_price_original.csv')
df.isnull().sum()
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı              260
# Bulunduğu_Kat          2297
# Eşya_Durumu            7398
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5576
# Takas                  5895
# Tapu_Durumu           10566
# Banyo_Sayısı             46
# dtype: int64

# %% [markdown]
# After seeing how many null values exist I thought of removing any rows with 4+ null values

# %%
import pandas as pd

df = pd.read_csv('home_price_original.csv')
# Nulls per column
df.dropna()
print(df.isnull().sum())

# Count nulls per row
nulls_per_row = df.isnull().sum(axis=1)

# Count rows before deletion
rows_before = len(df)

# Keep only rows with less than 4 nulls
df = df[nulls_per_row <= 4]

# Count rows after deletion
rows_after = len(df)
rows_deleted = rows_before - rows_after

# Stats
rows_with_nulls = df.isnull().any(axis=1).sum()
rows_with_2_nulls = (nulls_per_row == 2).sum()
rows_with_3_nulls = (nulls_per_row == 3).sum()

print(f"Rows before cleaning: {rows_before}")
print(f"Rows after cleaning: {rows_after}")
print(f"Rows deleted (>=4 nulls): {rows_deleted}")
print(f"Rows with at least one null (remaining): {rows_with_nulls}")
print(f"Rows with exactly 2 nulls (original): {rows_with_2_nulls}")
print(f"Rows with exactly 3 nulls (original): {rows_with_3_nulls}")

# Optional: save cleaned dataset
df.to_csv('home_price_cleaned.csv', index=False)
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı              260
# Bulunduğu_Kat          2297
# Eşya_Durumu            7398
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5576
# Takas                  5895
# Tapu_Durumu           10566
# Banyo_Sayısı             46
# dtype: int64
# Rows before cleaning: 20326
# Rows after cleaning: 19936
# Rows deleted (>=4 nulls): 390
# Rows with at least one null (remaining): 14745
# Rows with exactly 2 nulls (original): 2904
# Rows with exactly 3 nulls (original): 1441

# %% [markdown]
# visualization of the data and null values after making the change

# %%
df = pd.read_csv('home_price_cleaned.csv') 
print(df.isnull().sum())
rows_with_nulls = df.isnull().any(axis=1).sum()
print(f"Number of rows with null values: {rows_with_nulls}")
df.shape
df.info()
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı              211
# Bulunduğu_Kat          1983
# Eşya_Durumu            7008
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5186
# Takas                  5508
# Tapu_Durumu           10178
# Banyo_Sayısı              0
# dtype: int64
# Number of rows with null values: 14745
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19936 entries, 0 to 19935
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Net_Metrekare       19936 non-null  int64
#  1   Brüt_Metrekare      19936 non-null  float64
#  2   Oda_Sayısı          19725 non-null  float64
#  3   Bulunduğu_Kat       17953 non-null  object
#  4   Eşya_Durumu         12928 non-null  object
#  5   Binanın_Yaşı        19936 non-null  object
#  6   Isıtma_Tipi         19936 non-null  object
#  7   Fiyat               19936 non-null  float64
#  8   Şehir               19936 non-null  object
#  9   Binanın_Kat_Sayısı  19936 non-null  int64
#  10  Kullanım_Durumu     19936 non-null  object
#  11  Yatırıma_Uygunluk   14750 non-null  object
#  12  Takas               14428 non-null  object
#  13  Tapu_Durumu         9758 non-null   object
#  14  Banyo_Sayısı        19936 non-null  float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# set Null room values to banyo + 1

# %%
df = pd.read_csv('home_price_cleaned.csv')
df.loc[df.Oda_Sayısı.isnull(), 'Oda_Sayısı'] = df.Banyo_Sayısı + 1
df.to_csv('home_price_cleaned.csv', index=False)
print(df.isnull().sum())
print(df['Oda_Sayısı'].unique())
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı                0
# Bulunduğu_Kat          1983
# Eşya_Durumu            7008
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5186
# Takas                  5508
# Tapu_Durumu           10178
# Banyo_Sayısı              0
# dtype: int64
# [ 4.   3.   2.   5.   6.   4.5 11.   8.   5.5  7.   3.5  9.   1.  10.
#   2.5 12. ]

# %% [markdown]
# set all takas to Yok (setting Takas to bilinmiyor was also tested but was observed to make the model overfit so I settled with setting it to Yok)

# %%
df.loc[df.Takas.isnull(), 'Takas'] = 'Yok'
df.to_csv('home_price_cleaned.csv', index=False)
df = pd.read_csv('home_price_cleaned.csv')
print(df.isnull().sum())
print(df['Takas'].unique())
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı                0
# Bulunduğu_Kat          1983
# Eşya_Durumu            7008
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5186
# Takas                     0
# Tapu_Durumu           10178
# Banyo_Sayısı              0
# dtype: int64
# ['Var' 'Yok']

# %% [markdown]
# set all the rest of the null values to Bilinmiyor

# %%
df.loc[df.Eşya_Durumu.isnull(), 'Eşya_Durumu'] = 'Bilinmiyor'
df.to_csv('home_price_cleaned.csv', index=False)
df = pd.read_csv('home_price_cleaned.csv')
print(df.isnull().sum())
print(df['Eşya_Durumu'].unique())
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı                0
# Bulunduğu_Kat          1983
# Eşya_Durumu               0
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk      5186
# Takas                     0
# Tapu_Durumu           10178
# Banyo_Sayısı              0
# dtype: int64
# ['Eşyalı' 'Boş' 'Bilinmiyor']

# %%
df.loc[df.Yatırıma_Uygunluk.isnull(), 'Yatırıma_Uygunluk'] = 'Bilinmiyor'
df.to_csv('home_price_cleaned.csv', index=False)
df = pd.read_csv('home_price_cleaned.csv')
print(df.isnull().sum())
print(df['Yatırıma_Uygunluk'].unique())
# Out:
# Net_Metrekare             0
# Brüt_Metrekare            0
# Oda_Sayısı                0
# Bulunduğu_Kat          1983
# Eşya_Durumu               0
# Binanın_Yaşı              0
# Isıtma_Tipi               0
# Fiyat                     0
# Şehir                     0
# Binanın_Kat_Sayısı        0
# Kullanım_Durumu           0
# Yatırıma_Uygunluk         0
# Takas                     0
# Tapu_Durumu           10178
# Banyo_Sayısı              0
# dtype: int64
# ['Bilinmiyor' 'Uygun']

# %%
df.loc[df.Tapu_Durumu.isnull(), 'Tapu_Durumu'] = 'Bilinmiyor'
df.to_csv('home_price_cleaned.csv', index=False)
df = pd.read_csv('home_price_cleaned.csv')
print(df.isnull().sum())
print(df['Tapu_Durumu'].unique())
# Out:
# Net_Metrekare            0
# Brüt_Metrekare           0
# Oda_Sayısı               0
# Bulunduğu_Kat         1983
# Eşya_Durumu              0
# Binanın_Yaşı             0
# Isıtma_Tipi              0
# Fiyat                    0
# Şehir                    0
# Binanın_Kat_Sayısı       0
# Kullanım_Durumu          0
# Yatırıma_Uygunluk        0
# Takas                    0
# Tapu_Durumu              0
# Banyo_Sayısı             0
# dtype: int64
# ['Kat Mülkiyeti' 'Bilinmiyor' 'Kat İrtifakı' 'Müstakil Tapulu'
#  'Arsa Tapulu' 'Hisseli Tapu']

# %%
df.loc[df.Bulunduğu_Kat.isnull(), 'Bulunduğu_Kat'] = 'Bilinmiyor'
df.to_csv('home_price_cleaned.csv', index=False)
df = pd.read_csv('home_price_cleaned.csv')
print(df.isnull().sum())
print(df['Bulunduğu_Kat'].unique())
# Out:
# Net_Metrekare         0
# Brüt_Metrekare        0
# Oda_Sayısı            0
# Bulunduğu_Kat         0
# Eşya_Durumu           0
# Binanın_Yaşı          0
# Isıtma_Tipi           0
# Fiyat                 0
# Şehir                 0
# Binanın_Kat_Sayısı    0
# Kullanım_Durumu       0
# Yatırıma_Uygunluk     0
# Takas                 0
# Tapu_Durumu           0
# Banyo_Sayısı          0
# dtype: int64
# ['4.Kat' '3.Kat' '6.Kat' 'Düz Giriş (Zemin)' '12.Kat' '2.Kat' 'Bilinmiyor'
#  '8.Kat' '5.Kat' '14.Kat' '16.Kat' '1.Kat' '17.Kat' '9.Kat' 'Yüksek Giriş'
#  '7.Kat' '11.Kat' 'Müstakil' 'Bahçe Katı' '10.Kat' '15.Kat' 'Bahçe Dublex'
#  '13.Kat' 'Kot 3 (-3).Kat' 'Villa Tipi' '18.Kat' 'Çatı Dubleks' '21.Kat'
#  'Kot 2 (-2).Kat' 'Bodrum Kat' 'Çatı Katı' '26.Kat' 'Kot 1 (-1).Kat'
#  'Kot 4 (-4).Kat' '40+.Kat' '19.Kat' '30.Kat' '22.Kat']

# %% [markdown]
# remove extreme and impossible outliers from the data being careful not to delete legitimate house data which would lead to overfitting

# %%
def review_and_optionally_delete(df, condition, description):


    outliers = df[condition]

    if outliers.empty:
        print(f"\nNo outliers found for: {description}")
        return df
    
    print(f"\n==============================")
    print(f"OUTLIERS FOUND: {description}")
    print(f"Count: {len(outliers)}")
    print(outliers.head(10))  # show first 10 outliers
    print("==============================")

    choice = input("Delete these rows? (y/n): ").strip().lower()
    
    if choice == "y":
        print("Deleting rows...\n")
        df = df[~condition]
    else:
        print("Keeping all rows.\n")

    return df

# Make a working copy
clean_df = pd.read_csv("home_price_cleaned.csv")


condition = ~clean_df["Net_Metrekare"].between(10, 2000)
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Unrealistic Net_Metrekare (<10 or >2000)")


condition = ~clean_df["Brüt_Metrekare"].between(20, 4000)
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Unrealistic Brüt_Metrekare (<20 or >4000)")


condition = clean_df["Net_Metrekare"] > clean_df["Brüt_Metrekare"]
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Net_Metrekare greater than Brüt_Metrekare")


condition = ~clean_df["Oda_Sayısı"].between(0.5, 15)
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Unrealistic Oda_Sayısı (not between 0.5 and 15)")

condition = ~clean_df["Banyo_Sayısı"].between(0, 10)
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Unrealistic Banyo_Sayısı (not between 0 and 10)")

condition = clean_df["Banyo_Sayısı"] > clean_df["Oda_Sayısı"] + 2
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Banyo_Sayısı > Oda_Sayısı + 2")

# Negative or too small price
condition = clean_df["Fiyat"] <= 300000
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Fiyat ≤ 300000 TL (incorrect low price)")

condition = clean_df["Fiyat"] >= 500_000_000
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Fiyat ≥ 500M TL (unrealistic high price)")


condition = ~clean_df["Binanın_Kat_Sayısı"].between(1, 200)
clean_df = review_and_optionally_delete(clean_df, condition,
                                        "Unrealistic Binanın_Kat_Sayısı (not between 1 and 200)")

# =============================================
# IMPROVED STATISTICAL OUTLIERS (Less Aggressive)
# =============================================

if len(clean_df) > 10:
    # Calculate price per m2
    price_per_m2 = clean_df["Fiyat"] / clean_df["Net_Metrekare"]
    
    # Use IQR method instead of Z-score (less sensitive to outliers)
    Q1 = price_per_m2.quantile(0.25)
    Q3 = price_per_m2.quantile(0.75)
    IQR = Q3 - Q1
    
    # Conservative outlier boundaries (1.5x IQR is standard, 3x is very conservative)
    lower_bound = Q1 - (3 * IQR)
    upper_bound = Q3 + (3 * IQR)
    
    # Alternative: Use Z-score with higher threshold OR log transformation
    z_scores = np.abs((price_per_m2 - price_per_m2.mean()) / price_per_m2.std())
    
    # Only flag EXTREME outliers (z-score > 10 instead of 5)
    extreme_z_outliers = z_scores > 10
    
    # Flag IQR outliers
    iqr_outliers = (price_per_m2 < lower_bound) | (price_per_m2 > upper_bound)
    
    # Combine: Only remove if BOTH methods agree it's an outlier
    # This is very conservative - only removes clear errors
    combined_outliers = extreme_z_outliers & iqr_outliers
    
    # OR: Use percentile-based approach (remove top/bottom 0.1%)
    percentile_lower = price_per_m2.quantile(0.001)
    percentile_upper = price_per_m2.quantile(0.999)
    percentile_outliers = (price_per_m2 < percentile_lower) | (price_per_m2 > percentile_upper)
    
    print(f"\nPrice per m² statistics:")
    print(f"  Mean: {price_per_m2.mean():,.0f} TL/m²")
    print(f"  Std: {price_per_m2.std():,.0f} TL/m²")
    print(f"  Q1 (25th percentile): {Q1:,.0f} TL/m²")
    print(f"  Q3 (75th percentile): {Q3:,.0f} TL/m²")
    print(f"  IQR bounds (Q1-3IQR to Q3+3IQR): {lower_bound:,.0f} to {upper_bound:,.0f} TL/m²")
    print(f"  0.1% to 99.9% range: {percentile_lower:,.0f} to {percentile_upper:,.0f} TL/m²")
    
    # Choose the most appropriate method (I recommend IQR with 3x multiplier)
    outliers_to_remove = iqr_outliers  # or combined_outliers or percentile_outliers
    
    if outliers_to_remove.any():
        outlier_count = outliers_to_remove.sum()
        percentage = (outlier_count / len(clean_df)) * 100
        
        print(f"\nFound {outlier_count} statistical outliers ({percentage:.2f}% of data)")
        
        # Show distribution before deciding
        print("\nOutlier price per m² range:")
        outlier_prices = price_per_m2[outliers_to_remove]
        print(f"  Min: {outlier_prices.min():,.0f} TL/m²")
        print(f"  Max: {outlier_prices.max():,.0f} TL/m²")
        print(f"  Avg: {outlier_prices.mean():,.0f} TL/m²")
        
        choice = input(f"\nReview these {outlier_count} outliers? (y/n): ").strip().lower()
        
        if choice == "y":
            # Show the outliers
            outlier_df = clean_df[outliers_to_remove].copy()
            outlier_df["Price_per_m2"] = outlier_df["Fiyat"] / outlier_df["Net_Metrekare"]
            
            # Calculate how extreme they are
            outlier_df["Deviation_pct"] = ((outlier_df["Price_per_m2"] - price_per_m2.mean()) / price_per_m2.mean()) * 100
            
            print(outlier_df[["Fiyat", "Net_Metrekare", "Price_per_m2", "Deviation_pct"]]
                  .sort_values("Price_per_m2", ascending=False)
                  .head(20))
            
            print(f"\nThese are {outlier_count} most extreme values:")
            print(f"  - Above: {(price_per_m2[outliers_to_remove] > upper_bound).sum()} above upper bound")
            print(f"  - Below: {(price_per_m2[outliers_to_remove] < lower_bound).sum()} below lower bound")
            
            delete_choice = input(f"\nDelete {outlier_count} outliers? (y/n): ").strip().lower()
            
            if delete_choice == "y":
                # Keep a copy of outliers for analysis
                outliers_removed = clean_df[outliers_to_remove].copy()
                
                # Remove outliers
                clean_df = clean_df[~outliers_to_remove]
                
                print(f"Removed {outlier_count} outliers ({percentage:.2f}% of data)")
                
                # Optional: Save removed outliers for analysis
                if input("Save removed outliers to separate file? (y/n): ").lower() == "y":
                    outliers_removed.to_csv("removed_outliers_analysis.csv", index=False, encoding='utf-8-sig')
                    print("Outliers saved to 'removed_outliers_analysis.csv'")
output_filename = "home_price_encoded_outlier.csv"
clean_df.to_csv(output_filename, index=False, encoding='utf-8-sig')
print(f"\n✓ Cleaned data saved to: {output_filename}")
print(f"✓ File contains {len(clean_df)} rows and {len(clean_df.columns)} columns")


print("\n" + "="*50)
print("CLEANING COMPLETE - SUMMARY")
print("="*50)
print(f"Original dataset rows: {len(df)}")
print(f"Cleaned dataset rows:  {len(clean_df)}")
print(f"Total rows removed:    {len(df) - len(clean_df)}")
print(f"Removal percentage:    {(len(df) - len(clean_df)) / len(df) * 100:.2f}%")
print("="*50)

# Optional: Show first few rows of cleaned data
if input("\nShow first 5 rows of cleaned data? (y/n): ").lower() == "y":
    print("\nFirst 5 rows of cleaned data:")
    print(clean_df.head())
# Out:
# ==============================
# OUTLIERS FOUND: Unrealistic Net_Metrekare (<10 or >2000)
# Count: 35
#       Net_Metrekare  Brüt_Metrekare  Oda_Sayısı Bulunduğu_Kat Eşya_Durumu  \
# 192            3698          3700.0         4.0    Bilinmiyor         Boş
# 1035              1             2.0         5.0  Yüksek Giriş         Boş
# 1050              2             3.0         3.0        12.Kat  Bilinmiyor
# 1880           2661          2665.0         3.0    Bilinmiyor  Bilinmiyor
# 1981          12500         25000.0         5.5    Bilinmiyor      Eşyalı
# 1994          11308         11310.0         7.0    Bilinmiyor  Bilinmiyor
# 2065              5            40.0         2.0         1.Kat  Bilinmiyor
# 2324           4499          4500.0         8.0    Bilinmiyor  Bilinmiyor
# 3379          16500         17000.0         7.0    Bilinmiyor      Eşyalı
# 3540              2            45.0         2.0         2.Kat  Bilinmiyor
#
#      Binanın_Yaşı       Isıtma_Tipi        Fiyat           Şehir  \
# 192          5-10            Sobalı    3350000.0           adana
# 1035     0 (Yeni)    Kombi Doğalgaz    2980000.0           adana
# 1050            2    Kombi Doğalgaz    2380000.0           adana
# 1880        11-15    Kat Kaloriferi    2550000.0  afyonkarahisar
# 1981        11-15  Merkezi Doğalgaz   13250000.0  afyonkarahisar
# 1994     0 (Yeni)        Isıtma Yok    1250000.0  afyonkarahisar
# 2065     0 (Yeni)   Doğalgaz Sobalı     950000.0         aksaray
# 2324         5-10    Kat Kaloriferi   14500000.0          amasya
# 3379         5-10    Kat Kaloriferi  235000000.0         antalya
# 3540     0 (Yeni)           Klimalı    6500000.0         antalya
#
#       Binanın_Kat_Sayısı       Kullanım_Durumu Yatırıma_Uygunluk Takas  \
# 192                    1                   Boş        Bilinmiyor   Var
# 1035                  13                   Boş             Uygun   Yok
# 1050                  15  Mülk Sahibi Oturuyor        Bilinmiyor   Yok
# 1880                   1                   Boş             Uygun   Yok
# 1981                   1  Mülk Sahibi Oturuyor             Uygun   Var
# 1994                   1                   Boş        Bilinmiyor   Var
# 2065                   3                   Boş        Bilinmiyor   Yok
# 2324                   3                   Boş        Bilinmiyor   Yok
# 3379                   3                   Boş             Uygun   Yok
# 3540                   4                   Boş             Uygun   Yok
#
#           Tapu_Durumu  Banyo_Sayısı
# 192   Müstakil Tapulu           1.0
# 1035    Kat Mülkiyeti           2.0
# 1050    Kat Mülkiyeti           2.0
# 1880       Bilinmiyor           1.0
# 1981    Kat Mülkiyeti           2.0
# 1994      Arsa Tapulu           6.0
# 2065       Bilinmiyor           1.0
# 2324    Kat Mülkiyeti           4.0
# 3379  Müstakil Tapulu           6.0
# 3540       Bilinmiyor           1.0
# ==============================
# Deleting rows...
#
#
# ==============================
# OUTLIERS FOUND: Unrealistic Brüt_Metrekare (<20 or >4000)
# Count: 11
#        Net_Metrekare  Brüt_Metrekare  Oda_Sayısı Bulunduğu_Kat Eşya_Durumu  \
# 5368              80    2.922222e+13         3.0    Bilinmiyor      Eşyalı
# 6258             400    1.028400e+04         4.0    Bilinmiyor  Bilinmiyor
# 6565              50    6.357000e+03         3.0    Bilinmiyor         Boş
# 6612             190    5.000000e+03         3.0    Bilinmiyor         Boş
# 12893            200    7.000000e+03         6.0    Bilinmiyor  Bilinmiyor
# 14208           1800    6.500000e+03         5.0    Bilinmiyor      Eşyalı
# 14747            170    5.225000e+03         5.0    Villa Tipi  Bilinmiyor
# 16423            300    6.206000e+03         6.0    Bilinmiyor      Eşyalı
# 18003            230    6.649000e+03         4.0    Bilinmiyor      Eşyalı
# 18099            210    4.200000e+03         3.0    Bilinmiyor      Eşyalı
#
#       Binanın_Yaşı     Isıtma_Tipi       Fiyat       Şehir  \
# 5368   21 Ve Üzeri          Sobalı   1500000.0      burdur
# 6258          5-10          Sobalı   9500000.0       bursa
# 6565             1          Sobalı   6500000.0   canakkale
# 6612   21 Ve Üzeri          Sobalı  37500000.0   canakkale
# 12893         5-10          Sobalı   7300000.0   eskisehir
# 14208     0 (Yeni)  Kat Kaloriferi  25000000.0   gaziantep
# 14747     0 (Yeni)  Kat Kaloriferi   3500000.0     giresun
# 16423        11-15          Sobalı   5750000.0     karabuk
# 18003            1  Güneş Enerjisi  17000000.0  kirklareli
# 18099            2  Kombi Doğalgaz   8720000.0  kirklareli
#
#        Binanın_Kat_Sayısı       Kullanım_Durumu Yatırıma_Uygunluk Takas  \
# 5368                    1                   Boş             Uygun   Yok
# 6258                    1                   Boş        Bilinmiyor   Yok
# 6565                    1  Mülk Sahibi Oturuyor        Bilinmiyor   Var
# 6612                    2                   Boş        Bilinmiyor   Yok
# 12893                   2                   Boş             Uygun   Var
# 14208                   1  Mülk Sahibi Oturuyor             Uygun   Yok
# 14747                   2                   Boş             Uygun   Yok
# 16423                   2  Mülk Sahibi Oturuyor             Uygun   Var
# 18003                   2  Mülk Sahibi Oturuyor             Uygun   Yok
# 18099                   2                   Boş        Bilinmiyor   Yok
#
#            Tapu_Durumu  Banyo_Sayısı
# 5368   Müstakil Tapulu           1.0
# 6258   Müstakil Tapulu           2.0
# 6565   Müstakil Tapulu           1.0
# 6612   Müstakil Tapulu           2.0
# 12893  Müstakil Tapulu           1.0
# 14208  Müstakil Tapulu           2.0
# 14747       Bilinmiyor           2.0
# 16423    Kat Mülkiyeti           2.0
# 18003    Kat Mülkiyeti           3.0
# 18099  Müstakil Tapulu           1.0
# ==============================
# Deleting rows...
#
#
# No outliers found for: Net_Metrekare greater than Brüt_Metrekare
#
# No outliers found for: Unrealistic Oda_Sayısı (not between 0.5 and 15)
#
# No outliers found for: Unrealistic Banyo_Sayısı (not between 0 and 10)
#
# ==============================
# OUTLIERS FOUND: Banyo_Sayısı > Oda_Sayısı + 2
# Count: 21
#       Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat  \
# 198              50            60.0         2.0       Yüksek Giriş
# 632             125           130.0         1.0  Düz Giriş (Zemin)
# 1067             45            60.0         2.0              1.Kat
# 1957            105           106.0         1.0         Bilinmiyor
# 1973             65            70.0         3.0              3.Kat
# 2504            400           837.0         3.0         Bilinmiyor
# 2939             40            55.0         1.0              2.Kat
# 3220             85            95.0         3.0              2.Kat
# 3459            120           125.0         3.0              3.Kat
# 4550             40            50.0         2.0       Yüksek Giriş
#
#      Eşya_Durumu Binanın_Yaşı          Isıtma_Tipi       Fiyat  \
# 198          Boş     0 (Yeni)      Doğalgaz Sobalı   1450000.0
# 632          Boş            1  Merkezi (Pay Ölçer)  10500000.0
# 1067         Boş        16-20              Klimalı    450000.0
# 1957  Bilinmiyor  21 Ve Üzeri       Kombi Doğalgaz  10500000.0
# 1973      Eşyalı            2       Kombi Doğalgaz   1990000.0
# 2504         Boş     0 (Yeni)           Isıtma Yok  28000000.0
# 2939         Boş     0 (Yeni)              Klimalı   2000000.0
# 3220  Bilinmiyor     0 (Yeni)           Isıtma Yok   2650000.0
# 3459  Bilinmiyor        11-15      Doğalgaz Sobalı   1600000.0
# 4550         Boş     0 (Yeni)       Kombi Doğalgaz    775000.0
#
#                Şehir  Binanın_Kat_Sayısı  Kullanım_Durumu Yatırıma_Uygunluk  \
# 198            adana                  12              Boş        Bilinmiyor
# 632            adana                  10              Boş        Bilinmiyor
# 1067           adana                  12  Kiracı Oturuyor        Bilinmiyor
# 1957  afyonkarahisar                   3              Boş        Bilinmiyor
# 1973  afyonkarahisar                   4  Kiracı Oturuyor             Uygun
# 2504         antalya                   4              Boş        Bilinmiyor
# 2939         antalya                   4              Boş             Uygun
# 3220         antalya                   5              Boş        Bilinmiyor
# 3459         antalya                   3              Boş        Bilinmiyor
# 4550          batman                   4              Boş        Bilinmiyor
#
#      Takas    Tapu_Durumu  Banyo_Sayısı
# 198    Yok  Kat Mülkiyeti           6.0
# 632    Yok     Bilinmiyor           6.0
# 1067   Var     Bilinmiyor           6.0
# 1957   Yok     Bilinmiyor           6.0
# 1973   Yok  Kat Mülkiyeti           6.0
# 2504   Yok     Bilinmiyor           6.0
# 2939   Yok  Kat Mülkiyeti           6.0
# 3220   Var   Kat İrtifakı           6.0
# 3459   Yok     Bilinmiyor           6.0
# 4550   Yok     Bilinmiyor           6.0
# ==============================
# Deleting rows...
#
#
# ==============================
# OUTLIERS FOUND: Fiyat ≤ 300000 TL (incorrect low price)
# Count: 52
#       Net_Metrekare  Brüt_Metrekare  Oda_Sayısı   Bulunduğu_Kat Eşya_Durumu  \
# 1844             80            90.0         2.5           3.Kat      Eşyalı
# 1846             86            87.0         3.0      Bilinmiyor         Boş
# 1852             65            70.0         2.0           3.Kat      Eşyalı
# 1874             60            70.0         2.0           2.Kat      Eşyalı
# 1936             92            99.0         2.0           4.Kat      Eşyalı
# 1953             70            75.0         2.0           3.Kat  Bilinmiyor
# 2018             78            80.0         2.0           4.Kat      Eşyalı
# 2020             85            90.0         2.0  Kot 3 (-3).Kat      Eşyalı
# 2441            126           130.0         4.0           2.Kat  Bilinmiyor
# 2454             29            30.0         2.0      Bilinmiyor  Bilinmiyor
#
#      Binanın_Yaşı    Isıtma_Tipi     Fiyat           Şehir  \
# 1844         5-10      Jeotermal   25000.0  afyonkarahisar
# 1846         5-10         Sobalı  225000.0  afyonkarahisar
# 1852        11-15      Jeotermal   65000.0  afyonkarahisar
# 1874         5-10      Jeotermal   70000.0  afyonkarahisar
# 1936         5-10      Jeotermal  100000.0  afyonkarahisar
# 1953         5-10      Jeotermal   75000.0  afyonkarahisar
# 2018         5-10  Yerden Isıtma   75000.0  afyonkarahisar
# 2020            4      Jeotermal   75000.0  afyonkarahisar
# 2441     0 (Yeni)        Klimalı  111111.0         antalya
# 2454     0 (Yeni)         Sobalı  270000.0         antalya
#
#       Binanın_Kat_Sayısı       Kullanım_Durumu Yatırıma_Uygunluk Takas  \
# 1844                   7                   Boş             Uygun   Yok
# 1846                   1                   Boş             Uygun   Var
# 1852                   5                   Boş        Bilinmiyor   Yok
# 1874                   5                   Boş             Uygun   Yok
# 1936                   6                   Boş             Uygun   Yok
# 1953                   5                   Boş        Bilinmiyor   Yok
# 2018                   5                   Boş             Uygun   Var
# 2020                   3                   Boş             Uygun   Var
# 2441                   5                   Boş        Bilinmiyor   Yok
# 2454                   1  Mülk Sahibi Oturuyor        Bilinmiyor   Yok
#
#           Tapu_Durumu  Banyo_Sayısı
# 1844      Arsa Tapulu           1.0
# 1846  Müstakil Tapulu           1.0
# 1852       Bilinmiyor           1.0
# 1874       Bilinmiyor           1.0
# 1936       Bilinmiyor           1.0
# 1953       Bilinmiyor           1.0
# 2018    Kat Mülkiyeti           1.0
# 2020       Bilinmiyor           1.0
# 2441       Bilinmiyor           2.0
# 2454       Bilinmiyor           1.0
# ==============================
# Deleting rows...
#
#
# ==============================
# OUTLIERS FOUND: Fiyat ≥ 500M TL (unrealistic high price)
# Count: 11
#        Net_Metrekare  Brüt_Metrekare  Oda_Sayısı      Bulunduğu_Kat  \
# 1548            1550          1552.0         4.0              2.Kat
# 1609             110           120.0         4.0              2.Kat
# 8741             200           220.0         5.0       Çatı Dubleks
# 10597            140           150.0         4.0              2.Kat
# 10837            125           130.0         5.0         Bilinmiyor
# 11862            155           165.0         4.0             10.Kat
# 13815             85            95.0         3.0              4.Kat
# 15172             70            85.0         3.0              3.Kat
# 17037            135           170.0         4.0              3.Kat
# 18587            195           200.0         8.0  Düz Giriş (Zemin)
#
#       Eşya_Durumu Binanın_Yaşı       Isıtma_Tipi         Fiyat  \
# 1548          Boş            4            Sobalı  3.250000e+09
# 1609          Boş     0 (Yeni)    Kombi Doğalgaz  2.550000e+09
# 8741   Bilinmiyor         5-10  Merkezi Doğalgaz  1.899000e+09
# 10597  Bilinmiyor        11-15    Kombi Doğalgaz  2.100000e+09
# 10837  Bilinmiyor         5-10            Sobalı  7.500000e+09
# 11862  Bilinmiyor            3    Kombi Doğalgaz  1.750000e+09
# 13815         Boş         5-10    Kombi Doğalgaz  1.400000e+09
# 15172  Bilinmiyor        11-15    Kat Kaloriferi  8.600000e+08
# 17037         Boş        11-15  Merkezi Doğalgaz  1.800000e+09
# 18587      Eşyalı         5-10    Kombi Doğalgaz  3.250000e+09
#
#                 Şehir  Binanın_Kat_Sayısı       Kullanım_Durumu  \
# 1548   afyonkarahisar                   2                   Boş
# 1609   afyonkarahisar                   4                   Boş
# 8741          denizli                   5                   Boş
# 10597      diyarbakir                   6  Mülk Sahibi Oturuyor
# 10837           duzce                   2                   Boş
# 11862          elazig                  11  Mülk Sahibi Oturuyor
# 13815       gaziantep                  10  Mülk Sahibi Oturuyor
# 15172           hatay                   4       Kiracı Oturuyor
# 17037         kayseri                   8                   Boş
# 18587         kocaeli                   3  Mülk Sahibi Oturuyor
#
#       Yatırıma_Uygunluk Takas      Tapu_Durumu  Banyo_Sayısı
# 1548         Bilinmiyor   Yok  Müstakil Tapulu           2.0
# 1609         Bilinmiyor   Yok    Kat Mülkiyeti           1.0
# 8741         Bilinmiyor   Yok       Bilinmiyor           2.0
# 10597             Uygun   Yok    Kat Mülkiyeti           1.0
# 10837        Bilinmiyor   Var       Bilinmiyor           2.0
# 11862        Bilinmiyor   Yok    Kat Mülkiyeti           2.0
# 13815             Uygun   Yok    Kat Mülkiyeti           1.0
# 15172        Bilinmiyor   Yok       Bilinmiyor           1.0
# 17037        Bilinmiyor   Yok       Bilinmiyor           2.0
# 18587        Bilinmiyor   Yok       Bilinmiyor           2.0
# ==============================
# Deleting rows...
#
#
# No outliers found for: Unrealistic Binanın_Kat_Sayısı (not between 1 and 200)
#
# Price per m² statistics:
#   Mean: 25,061 TL/m²
#   Std: 24,894 TL/m²
#   Q1 (25th percentile): 15,750 TL/m²
#   Q3 (75th percentile): 27,647 TL/m²
#   IQR bounds (Q1-3IQR to Q3+3IQR): -19,941 to 63,338 TL/m²
#   0.1% to 99.9% range: 1,844 to 242,542 TL/m²
#
# Found 645 statistical outliers (3.26% of data)
#
# Outlier price per m² range:
#   Min: 63,379 TL/m²
#   Max: 2,035,714 TL/m²
#   Avg: 104,593 TL/m²
#              Fiyat  Net_Metrekare  Price_per_m2  Deviation_pct
# 18480  285000000.0            140  2.035714e+06    8023.037603
# 11290  120000000.0            160  7.500000e+05    2892.698064
# 15652   22500000.0             49  4.591837e+05    1732.264121
# 3313    90000000.0            200  4.500000e+05    1695.618839
# 2654     4335000.0             10  4.335000e+05    1629.779481
# 6745    92500000.0            220  4.204545e+05    1577.724672
# 3934   200000000.0            500  4.000000e+05    1496.105634
# 15911   49000000.0            130  3.769231e+05    1404.022617
# 6013    24000000.0             65  3.692308e+05    1373.328278
# 6637    29000000.0             80  3.625000e+05    1346.470731
# 15756   73000000.0            220  3.318182e+05    1224.042174
# 4394     8500000.0             26  3.269231e+05    1204.509413
# 19511   39400000.0            130  3.030769e+05    1109.356961
# 6938    90000000.0            300  3.000000e+05    1097.079226
# 1915    29500000.0             99  2.979798e+05    1089.018086
# 7255    43000000.0            150  2.866667e+05    1043.875705
# 8353    13500000.0             48  2.812500e+05    1022.261774
# 8160    13750000.0             49  2.806122e+05    1019.716963
# 17976   60000000.0            230  2.608696e+05     940.938457
# 16797   32000000.0            130  2.461538e+05     882.218852
#
# These are 645 most extreme values:
#   - Above: 645 above upper bound
#   - Below: 0 below lower bound
# Removed 645 outliers (3.26% of data)
#
# ✓ Cleaned data saved to: home_price_encoded_outlier.csv
# ✓ File contains 19161 rows and 15 columns
#
# ==================================================
# CLEANING COMPLETE - SUMMARY
# ==================================================
# Original dataset rows: 19936
# Cleaned dataset rows:  19161
# Total rows removed:    775
# Removal percentage:    3.89%
# ==================================================

# %% [markdown]
# One-Hot Encoding the data

# %%
import pandas as pd

# 1. Load your dataset
# Replace 'your_dataset.csv' with your actual file name
input_file = 'home_price_encoded_outlier.csv'
output_file = 'home_price_cleaned_OHE.csv' 

df = pd.read_csv(input_file)

# 2. Define the categorical columns to encode
# These are selected based on the 'object' type in your info list
categorical_cols = [
    'Bulunduğu_Kat',
    'Eşya_Durumu',
    'Binanın_Yaşı', 
    'Isıtma_Tipi',
    'Şehir',
    'Kullanım_Durumu',
    'Yatırıma_Uygunluk',
    'Takas',
    'Tapu_Durumu'
]

# 3. Apply One-Hot Encoding
# dtype=int ensures the output is 0 and 1 instead of True and False
df_encoded = pd.get_dummies(df, columns=categorical_cols, dtype=int,drop_first=True)

# 4. Save the changes to a file
# index=False ensures we don't save the row numbers as a separate column
df_encoded.to_csv(output_file, index=False)

print(f"Encoding complete. Data saved to {output_file}")
print(f"Original shape: {df.shape}")
print(f"New shape: {df_encoded.shape}")
df = pd.read_csv('home_price_cleaned_OHE.csv')
df.info(verbose=True, show_counts=True)
# Out:
# Encoding complete. Data saved to home_price_cleaned_OHE.csv
# Original shape: (19161, 15)
# New shape: (19161, 124)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19161 entries, 0 to 19160
# Data columns (total 124 columns):
#  #    Column                                Non-Null Count  Dtype
# ---   ------                                --------------  -----
#  0    Net_Metrekare                         19161 non-null  int64
#  1    Brüt_Metrekare                        19161 non-null  float64
#  2    Oda_Sayısı                            19161 non-null  float64
#  3    Fiyat                                 19161 non-null  float64
#  4    Binanın_Kat_Sayısı                    19161 non-null  int64
#  5    Banyo_Sayısı                          19161 non-null  float64
#  6    Bulunduğu_Kat_10.Kat                  19161 non-null  int64
#  7    Bulunduğu_Kat_11.Kat                  19161 non-null  int64
#  8    Bulunduğu_Kat_12.Kat                  19161 non-null  int64
#  9    Bulunduğu_Kat_13.Kat                  19161 non-null  int64
#  10   Bulunduğu_Kat_14.Kat                  19161 non-null  int64
#  11   Bulunduğu_Kat_15.Kat                  19161 non-null  int64
#  12   Bulunduğu_Kat_16.Kat                  19161 non-null  int64
#  13   Bulunduğu_Kat_17.Kat                  19161 non-null  int64
#  14   Bulunduğu_Kat_18.Kat                  19161 non-null  int64
#  15   Bulunduğu_Kat_19.Kat                  19161 non-null  int64
#  16   Bulunduğu_Kat_2.Kat                   19161 non-null  int64
#  17   Bulunduğu_Kat_21.Kat                  19161 non-null  int64
#  18   Bulunduğu_Kat_22.Kat                  19161 non-null  int64
#  19   Bulunduğu_Kat_3.Kat                   19161 non-null  int64
#  20   Bulunduğu_Kat_4.Kat                   19161 non-null  int64
#  21   Bulunduğu_Kat_40+.Kat                 19161 non-null  int64
#  22   Bulunduğu_Kat_5.Kat                   19161 non-null  int64
#  23   Bulunduğu_Kat_6.Kat                   19161 non-null  int64
#  24   Bulunduğu_Kat_7.Kat                   19161 non-null  int64
#  25   Bulunduğu_Kat_8.Kat                   19161 non-null  int64
#  26   Bulunduğu_Kat_9.Kat                   19161 non-null  int64
#  27   Bulunduğu_Kat_Bahçe Dublex            19161 non-null  int64
#  28   Bulunduğu_Kat_Bahçe Katı              19161 non-null  int64
#  29   Bulunduğu_Kat_Bilinmiyor              19161 non-null  int64
#  30   Bulunduğu_Kat_Bodrum Kat              19161 non-null  int64
#  31   Bulunduğu_Kat_Düz Giriş (Zemin)       19161 non-null  int64
#  32   Bulunduğu_Kat_Kot 1 (-1).Kat          19161 non-null  int64
#  33   Bulunduğu_Kat_Kot 2 (-2).Kat          19161 non-null  int64
#  34   Bulunduğu_Kat_Kot 3 (-3).Kat          19161 non-null  int64
#  35   Bulunduğu_Kat_Kot 4 (-4).Kat          19161 non-null  int64
#  36   Bulunduğu_Kat_Müstakil                19161 non-null  int64
#  37   Bulunduğu_Kat_Villa Tipi              19161 non-null  int64
#  38   Bulunduğu_Kat_Yüksek Giriş            19161 non-null  int64
#  39   Bulunduğu_Kat_Çatı Dubleks            19161 non-null  int64
#  40   Bulunduğu_Kat_Çatı Katı               19161 non-null  int64
#  41   Eşya_Durumu_Boş                       19161 non-null  int64
#  42   Eşya_Durumu_Eşyalı                    19161 non-null  int64
#  43   Binanın_Yaşı_1                        19161 non-null  int64
#  44   Binanın_Yaşı_11-15                    19161 non-null  int64
#  45   Binanın_Yaşı_16-20                    19161 non-null  int64
#  46   Binanın_Yaşı_2                        19161 non-null  int64
#  47   Binanın_Yaşı_21 Ve Üzeri              19161 non-null  int64
#  48   Binanın_Yaşı_3                        19161 non-null  int64
#  49   Binanın_Yaşı_4                        19161 non-null  int64
#  50   Binanın_Yaşı_5-10                     19161 non-null  int64
#  51   Isıtma_Tipi_Doğalgaz Sobalı           19161 non-null  int64
#  52   Isıtma_Tipi_Güneş Enerjisi            19161 non-null  int64
#  53   Isıtma_Tipi_Isıtma Yok                19161 non-null  int64
#  54   Isıtma_Tipi_Jeotermal                 19161 non-null  int64
#  55   Isıtma_Tipi_Kat Kaloriferi            19161 non-null  int64
#  56   Isıtma_Tipi_Klimalı                   19161 non-null  int64
#  57   Isıtma_Tipi_Kombi Doğalgaz            19161 non-null  int64
#  58   Isıtma_Tipi_Merkezi (Pay Ölçer)       19161 non-null  int64
#  59   Isıtma_Tipi_Merkezi Doğalgaz          19161 non-null  int64
#  60   Isıtma_Tipi_Merkezi Kömür             19161 non-null  int64
#  61   Isıtma_Tipi_Sobalı                    19161 non-null  int64
#  62   Isıtma_Tipi_Yerden Isıtma             19161 non-null  int64
#  63   Şehir_adiyaman                        19161 non-null  int64
#  64   Şehir_afyonkarahisar                  19161 non-null  int64
#  65   Şehir_agri                            19161 non-null  int64
#  66   Şehir_aksaray                         19161 non-null  int64
#  67   Şehir_amasya                          19161 non-null  int64
#  68   Şehir_ankara                          19161 non-null  int64
#  69   Şehir_antalya                         19161 non-null  int64
#  70   Şehir_ardahan                         19161 non-null  int64
#  71   Şehir_artvin                          19161 non-null  int64
#  72   Şehir_aydin                           19161 non-null  int64
#  73   Şehir_balikesir                       19161 non-null  int64
#  74   Şehir_bartin                          19161 non-null  int64
#  75   Şehir_batman                          19161 non-null  int64
#  76   Şehir_bayburt                         19161 non-null  int64
#  77   Şehir_bilecik                         19161 non-null  int64
#  78   Şehir_bingol                          19161 non-null  int64
#  79   Şehir_bitlis                          19161 non-null  int64
#  80   Şehir_bolu                            19161 non-null  int64
#  81   Şehir_burdur                          19161 non-null  int64
#  82   Şehir_bursa                           19161 non-null  int64
#  83   Şehir_canakkale                       19161 non-null  int64
#  84   Şehir_cankiri                         19161 non-null  int64
#  85   Şehir_corum                           19161 non-null  int64
#  86   Şehir_denizli                         19161 non-null  int64
#  87   Şehir_diyarbakir                      19161 non-null  int64
#  88   Şehir_duzce                           19161 non-null  int64
#  89   Şehir_edirne                          19161 non-null  int64
#  90   Şehir_elazig                          19161 non-null  int64
#  91   Şehir_erzincan                        19161 non-null  int64
#  92   Şehir_erzurum                         19161 non-null  int64
#  93   Şehir_eskisehir                       19161 non-null  int64
#  94   Şehir_gaziantep                       19161 non-null  int64
#  95   Şehir_giresun                         19161 non-null  int64
#  96   Şehir_gumushane                       19161 non-null  int64
#  97   Şehir_hakkari                         19161 non-null  int64
#  98   Şehir_hatay                           19161 non-null  int64
#  99   Şehir_igdir                           19161 non-null  int64
#  100  Şehir_isparta                         19161 non-null  int64
#  101  Şehir_istanbul                        19161 non-null  int64
#  102  Şehir_izmir                           19161 non-null  int64
#  103  Şehir_kahramanmaras                   19161 non-null  int64
#  104  Şehir_karabuk                         19161 non-null  int64
#  105  Şehir_karaman                         19161 non-null  int64
#  106  Şehir_kars                            19161 non-null  int64
#  107  Şehir_kastamonu                       19161 non-null  int64
#  108  Şehir_kayseri                         19161 non-null  int64
#  109  Şehir_kilis                           19161 non-null  int64
#  110  Şehir_kirikkale                       19161 non-null  int64
#  111  Şehir_kirklareli                      19161 non-null  int64
#  112  Şehir_kirsehir                        19161 non-null  int64
#  113  Şehir_kocaeli                         19161 non-null  int64
#  114  Şehir_konya                           19161 non-null  int64
#  115  Kullanım_Durumu_Kiracı Oturuyor       19161 non-null  int64
#  116  Kullanım_Durumu_Mülk Sahibi Oturuyor  19161 non-null  int64
#  117  Yatırıma_Uygunluk_Uygun               19161 non-null  int64
#  118  Takas_Yok                             19161 non-null  int64
#  119  Tapu_Durumu_Bilinmiyor                19161 non-null  int64
#  120  Tapu_Durumu_Hisseli Tapu              19161 non-null  int64
#  121  Tapu_Durumu_Kat Mülkiyeti             19161 non-null  int64
#  122  Tapu_Durumu_Kat İrtifakı              19161 non-null  int64
#  123  Tapu_Durumu_Müstakil Tapulu           19161 non-null  int64
# dtypes: float64(4), int64(120)
# memory usage: 18.1 MB
